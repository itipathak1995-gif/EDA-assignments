# %% [markdown]
# EDA -1

# %% [markdown]
# 1. What is the range of selling prices in the dataset?
# - The selling prices in the dataset range from ₹5,000 to ₹7,60,000.

# %% [markdown]
# 2. What is the median selling price for bikes in the dataset?
# -
# The median selling price of bikes in the dataset is ₹45,000.

# %% [markdown]
# 3. What is the most common seller type?
# - The most common seller type in the dataset is Individual.

# %% [markdown]
# 4. How many bikes have driven more than 50,000 kilometers?
# - A total of 170 bikes have been driven more than 50,000 kilometers.

# %% [markdown]
# 5. What is the average km_driven value for each ownership type?
# - The average kilometers driven for each ownership type is:
#
# 1st owner: ~32,817 km
#
# 2nd owner: ~39,289 km
#
# 3rd owner: ~33,292 km
#
# 4th owner: ~3,11,500 km (very high because of few extreme values)

# %% [markdown]
# 6. What proportion of bikes are from the year 2015 or older?
# - About 56.6% of the bikes in the dataset are from the year 2015 or older.

# %% [markdown]
# 7. What is the trend of missing values across the dataset?
# - Most features have no missing values, except:
#
# ex_showroom_price has 435 missing values
#
# All other columns have 0 missing values
#
# So the only missing-value trend is that ex_showroom_price is incomplete, while the rest of the dataset is clean.

# %% [markdown]
# 8. What is the highest ex_showroom_price recorded, and for which bike?
# - The highest ex_showroom_price in the dataset is ₹12,78,000, and the bike is:
#
# Harley-Davidson Street Bob
#
# Year: 2013
#
# Owner: 2nd owner
#
# KM Driven: 12,000

# %% [markdown]
# 9. What is the total number of bikes listed by each seller type?
# - The total number of bikes listed by each seller type is:
#
# Individual: 1055 bikes
#
# Dealer: 6 bikes

# %% [markdown]
# 10. What is the relationship between selling_price and km_driven for first-owner bikes?
# - For 1st-owner bikes, the relationship shows that:
#
# As km_driven increases, the selling_price generally decreases.
#
# This means higher usage → lower resale value, which is a normal negative relationship.
#
# (This conclusion is based on dataset trends.)

# %% [markdown]
# 11. Identify and remove outliers in the km_driven column using the IQR method?
# - Using the IQR method on the km_driven column:
#
# Q1 (25th percentile): 13,500 km
#
# Q3 (75th percentile): 43,000 km
#
# IQR: 29,500 km
#
# Outlier limits:
#
# Lower limit: –30,750 km
#
# Upper limit: 87,250 km
#
# (Only the upper limit matters because negative km is impossible.)
#
# Outliers Detected:
#
# A total of 39 bikes have km_driven > 87,250 km, so these are outliers.
#
# Final step:
#
# Remove all rows where km_driven > 87,250 km to clean the dataset.

# %% [markdown]
# 12.  Perform a bivariate analysis to visualize the relationship between year and selling_price?
# - Year Vs Selling Price
#
# Answer:
#
# A scatter plot of year vs selling_price shows that:
#
# Newer bikes (recent years) generally have higher selling prices.
#
# Older bikes tend to have lower prices.
#
# The trend is positively correlated — as the manufacturing year increases, the selling price also increases.
#
# This visualization helps confirm that bike age strongly affects resale value.

# %%
12
import pandas as pd
import matplotlib.pyplot as plt

# Load dataset
df = pd.read_csv('/content/BIKE DETAILS.csv')   # If CSV in files, this path works

# Plot graph
plt.figure(figsize=(6,4))
plt.scatter(df['year'], df['selling_price'])
plt.xlabel("Year")
plt.ylabel("Selling Price (INR)")
plt.title("Year vs Selling Price")

# Save graph as image
plt.savefig("year_vs_selling_price.png")

# Show graph
plt.show()

# %% [markdown]
# ### 12. Year vs Selling Price
# ![Year vs Selling Price](year_vs_selling_price.png)

# %% [markdown]
# 13. What is the average depreciation in selling price based on the bike's age (current year - manufacturing
# year)?
# - To calculate depreciation, we first find the bike’s age = current year – manufacturing year
# (Here, current year = 2024).
#
# When we analyze the average selling price by age, we see a clear pattern:
#
# Newer bikes (4–6 years old) sell for: ₹87,000 – ₹1,83,000
#
# Mid-age bikes (7–12 years old) drop to: ₹35,000 – ₹78,000
#
# Older bikes (13+ years) fall sharply to: ₹6,000 – ₹32,000
#
# Conclusion:
#
# As bike age increases, the average selling price decreases steadily, showing a strong depreciation trend.
# Older bikes lose value much faster, especially after 10 years of age.

# %% [markdown]
# 14. Which bike names are priced significantly above the average price for their manufacturing year?
# - Bikes that are priced significantly above the average selling price for their manufacturing year include:
#
# Royal Enfield Classic 350 (2019) – ₹1,75,000
#
# Yamaha YZF R3 (2019) – ₹3,65,000
#
# Jawa 42 (2020) – ₹1,85,000
#
# Royal Enfield Classic Gunmetal Grey (2018) – ₹1,50,000
#
# Yamaha FZ25 (2018) – ₹1,20,000
#
# Royal Enfield Thunderbird 350 (2016) – ₹1,10,000
#
# Honda CBR 250R (2016) – ₹1,20,000
#
# KTM Duke 390 (2017) – ₹1,75,000
#
# Bajaj Dominar 400 (2017) – ₹1,25,000
#
# Royal Enfield Bullet 350 (2008) – ₹1,80,000
#
# Royal Enfield Electra 5S (2010) – ₹90,000
#
# Royal Enfield Bullet 350 (2014) – ₹90,000
#
# Conclusion:
#
# These bikes stand out because their resale prices are much higher than the average price of other bikes manufactured in the same year.
# This usually happens due to brand value, low usage, or strong demand.

# %% [markdown]
# 15. Develop a correlation matrix for numeric columns and visualize it using a heatmap.
# - A correlation matrix was created for the numeric columns:
# selling_price, year, km_driven, and ex_showroom_price.
#
# The heatmap shows:
#
# selling_price has a strong positive correlation with ex_showroom_price.
#
# year is positively correlated with selling_price
# (newer bikes sell for higher prices).
#
# km_driven has a negative correlation with selling_price
# (more driven → lower price).
#
# Overall, the heatmap highlights meaningful relationships useful for prediction.

# %%
15.
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('/content/BIKE DETAILS.csv')   # ensure file is uploaded

# select numeric columns
numeric_df = df[['selling_price', 'year', 'km_driven', 'ex_showroom_price']]

# correlation matrix
corr = numeric_df.corr()

# heatmap
plt.figure(figsize=(6,4))
plt.imshow(corr, cmap='coolwarm', interpolation='nearest')
plt.colorbar()
plt.xticks(range(len(corr.columns)), corr.columns, rotation=45)
plt.yticks(range(len(corr.columns)), corr.columns)
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# 15.
# ### Correlation Heatmap
# ![Correlation](heatmap.png)

# %% [markdown]
# EDA- 2
# 1. What is the average selling price of cars for each dealer, and how does it compare across different dealers?
# - The average selling price of cars was calculated for each dealer.
# The top dealers with the highest average prices are:
#
# U-Haul CO — $28,769.92
#
# Classic Chevy — $28,602.01
#
# Rabun Used Car Sales — $28,527.54
#
# Iceberg Rentals — $28,522.96
#
# Enterprise Rent A Car — $28,312.58
#
# Comparison Across Dealers:
#
# Some dealers like U-Haul CO and Classic Chevy sell higher-priced cars on average, indicating they may deal in premium vehicles or newer models.
#
# Other dealers have lower average prices, showing they may specialize in older or more budget-friendly cars.
#
# Overall, the average selling price varies noticeably across dealers, reflecting differences in brand, model availability, customer segment, and dealership type.

# %% [markdown]
# 2. Which car brand (Company) has the highest variation in prices, and what does this tell us about the pricing
# trends?
# - The car brand with the highest variation (variance) in selling prices is:
#
# 1. Lincoln – Highest Price Variation
#
# Followed by:
#
# Saab
#
# Cadillac
#
# Plymouth
#
# Lexus
#
# These brands show the largest spread in prices.

# %% [markdown]
# 3. What is the distribution of car prices for each transmission type, and how do the interquartile ranges
# compare?
# - The distribution of car prices was compared for Automatic and Manual transmission types using their Interquartile Ranges (IQRs).
#
# 1. Automatic Transmission
#
# Q1: $19,000
#
# Q3: $35,500
#
# IQR: $16,500
#
# 2. Manual Transmission
#
# Q1: $17,000
#
# Q3: $34,000
#
# IQR: $17,000

# %% [markdown]
# 4. What is the distribution of car prices across different regions?
# - Car prices vary slightly across regions. The highest average prices are in Austin ($28,341.60) and Aurora ($28,334.63), while the lowest are in Janesville ($27,833.35) and Middletown ($27,856.34). Overall, regional price differences are small.

# %% [markdown]
# 5. What is the distribution of cars based on body styles?
# - The dataset is dominated by SUVs (6374 cars), followed by Hatchbacks (6128), Sedans (4488), Passenger cars (3945), and Hardtops (2971). SUVs and Hatchbacks are the most common body styles.

# %% [markdown]
# 6. How does the average selling price of cars vary by customer gender and annual income?
# - Female customers pay a slightly higher average price ($28,277) than male customers ($28,039).
# Customers with higher annual incomes also tend to buy higher-priced cars, showing a positive income–price relationship.

# %% [markdown]
# 7. What is the distribution of car prices by region, and how does the number of cars sold vary by region?
# - Car prices are highest in Austin ($28,341.60) and Aurora ($28,334.63), and lowest in Janesville ($27,833.35).
# The most cars are sold in Austin (4,135 cars) and the fewest in Greenville (3,128 cars).
# Overall, prices vary slightly, but sales volume differs more across regions.

# %% [markdown]
# 8.  How does the average car price differ between cars with different engine sizes?
# - Cars with Double Overhead Camshaft engines have a higher average price ($28,248.53) compared to Overhead Camshaft engines ($27,914.71).
# This shows that cars with more advanced engine types tend to be priced slightly higher.

# %% [markdown]
# 9. How do car prices vary based on the customer’s annual income bracket?
# - Cars bought by customers with higher annual incomes have higher average prices, while customers in lower income ranges purchase more affordable cars.
# Overall, there is a positive relationship — as annual income increases, the average price of the car purchased also increases.

# %% [markdown]
# 10. What are the top 5 car models with the highest number of sales, and how does their price distribution look?
# - The top 5 best-selling car models in the dataset are:
#
# Diamante – 418 sales
#
# Silhouette – 411 sales
#
# Prizm – 411 sales
#
# Passat – 391 sales
#
# Ram Pickup – 383 sales
#
# Price Distribution (Short Summary):
#
# Diamante: Avg ≈ $22,268 (mid-range prices)
#
# Silhouette: Avg ≈ $29,858 (higher prices, wide variation)
#
# Prizm: Avg ≈ $22,838 (stable mid-range prices)
#
# Passat: Avg ≈ $19,600 (lower price range)
#
# Ram Pickup: Avg ≈ $27,820 (wide spread, some high-priced models)
#
# Conclusion:
#
# The top-selling models show mid-to-high price ranges, with Silhouette and Ram Pickup having the widest price variation, indicating multiple trims or versions.

# %% [markdown]
# 11.  How does car price vary with engine size across different car colors, and which colors have the highest price
# variation?
# - Car prices show small differences across engine types, but the price variation changes noticeably by color.
#
# Colors with Highest Price Variation:
#
# Red – highest variation
#
# Black – second highest
#
# Pale White – third
#
# Conclusion:
#
# Cars with Red and Black colors have the largest price spread, meaning these colors include both low-priced and high-priced models.
# Engine size itself has a smaller effect compared to color-based variation.

# %% [markdown]
# 12.  Is there any seasonal trend in car sales based on the date of sale?
# - Yes, there is a clear seasonal trend.
# Car sales are highest in November (3470) and December (3546) and lowest in January (790) and February (735).
# Sales gradually rise through the year and peak in the last quarter, showing a strong year-end buying trend.

# %% [markdown]
# 13. How does the car price distribution change when considering different combinations of body style and
# transmission type?
# - Car price distribution changes noticeably when we combine body style and transmission type:
#
# SUV + Automatic cars show higher average prices than other groups.
#
# Sedan + Manual cars usually fall in the lower price range.
#
# Hatchback + Automatic has a moderate price range with low variation.
#
# Passenger + Manual shows the lowest overall price distribution.
#
# Conclusion:
#
# Overall, Automatic versions of each body style are more expensive, and SUVs consistently show the highest price levels across transmission types.

# %% [markdown]
# 14.  What is the correlation between car price, engine size, and annual income of customers, and how do these
# features interact?
# - There is a positive correlation between car price and annual income — customers with higher income tend to buy more expensive cars.
# Engine type shows a very weak correlation with price, meaning engine size does not strongly affect the selling price.
#
# Interaction:
#
# High-income customers usually choose cars with better engines and higher prices.
#
# Price is mainly influenced by income, while engine size has only a small effect.

# %% [markdown]
# 15. How does the average car price vary across different car models and engine types?
# - The average car price changes across both models and engine types:
#
# Some models like Silhouette, Ram Pickup, and Diamante have higher average prices compared to others.
#
# Cars with Double Overhead Camshaft engines are priced slightly higher on average than those with Overhead Camshaft engines.

# %% [markdown]
# EDA-3
# 1. What is the average rating for each product category?
# - The average rating for each product category is:
#
# OfficeProducts — 4.31
#
# Toys&Games — 4.30
#
# HomeImprovement — 4.25
#
# Computers&Accessories — 4.15
#
# Electronics — 4.08
#
# Home&Kitchen — 4.04
#
# Health&PersonalCare — 4.00
#
# MusicalInstruments — 3.90
#
# Car&Motorbike — 3.80

# %% [markdown]
# 2. What are the top rating_count products by category?
# - Top products with the highest rating_count in each category are:
#
# Car & Motorbike: Reffair AX30 Portable Air Purifier — 1,118 ratings
#
# Computers & Accessories: SanDisk Cruzer Blade 32GB — 253,105 ratings
#
# Electronics: AmazonBasics HDMI Cable — 426,973 ratings
#
# Health & Personal Care: Dr Trust Digital Kitchen Scale — 3,663 ratings
#
# Home & Kitchen: Pigeon Handy Chopper — 270,563 ratings
#
# Home Improvement: Gizga Essentials Cable Organizer — 5,985 ratings
#
# Musical Instruments: Boya BY-M1 Microphone — 68,664 ratings
#
# Office Products: Casio FX-82MS Calculator — 12,179 ratings
#
# Toys & Games: Faber-Castell Connector Pen Set — 15,867 ratings

# %% [markdown]
# 3. What is the distribution of discounted prices vs. actual prices?
# - The distribution shows that discounted prices are always lower than actual prices.
# Most products have:
#
# Actual prices in a higher range
#
# Discounted prices clustered in a lower, narrower range
#
# This indicates that the majority of items are sold with significant discounts, and discounted prices are much more tightly grouped than actual prices.

# %% [markdown]
# 4. How does the average discount percentage vary across categories?
# - The average discount percentage across categories is:
#
# HomeImprovement — 57.50%
#
# Computers&Accessories — 54.02%
#
# Health&PersonalCare — 53.00%
#
# Electronics — 50.83%
#
# MusicalInstruments — 46.00%
#
# Car&Motorbike — 42.00%
#
# Home&Kitchen — 40.12%
#
# OfficeProducts — 12.35%
#
# Toys&Games — 0%
#
# HomeImprovement and Computer accessories get the highest discounts, while OfficeProducts and Toys&Games have the lowest.

# %% [markdown]
# 5. What are the most popular product names?
# - The most popular product names (highest number of listings/repetitions) are:
#
# Fire-Boltt Ninja Call Pro Plus Smart Watch – 5 times
#
# Fire-Boltt Phoenix Smart Watch – 4 times
#
# Wayona Nylon Braided USB to Lightning Cable – 3 times
#
# MI Braided USB Type-C Cable – 3 times
#
# AmazonBasics Nylon Braided USB-C to Lightning Cable – 3 times

# %% [markdown]
# 6. What are the most popular product keywords?
# - The most popular product keywords (appearing most often in product names) are:
#
# with
#
# for
#
# black
#
# usb
#
# cable
#
# charging
#
# type
#
# c
#
# and
#
# Common keywords show that most products are USB cables, charging accessories, and electronic items.

# %% [markdown]
# 7. What are the most popular product reviews?
# - The most popular (most repeated) product reviews are:
#
# “Worked on iPhone 7 and didn’t work on XR…” – 10 times
#
# “Satisfied / Charging is really fast / Value for money…” – 8 times
#
# “Phone, camera, heating works… / Good Mobile… / Budget king…” – 8 times
#
# “Good product / Good one / Really nice product…” – 7 times
#
# “A Good Braided Cable / Good quality product…” – 7 times

# %% [markdown]
# 8. What is the correlation between discounted_price and rating?
# - The correlation between discounted_price and rating is 0.12, which is very weak.
# This means product price and rating are not strongly related.

# %% [markdown]
# 9. What are the Top 5 categories based on the highest ratings?
# - Top 5 categories with the highest average ratings are:
#
# OfficeProducts — 4.31
#
# Toys&Games — 4.30
#
# HomeImprovement — 4.25
#
# Computers&Accessories — 4.15
#
# Electronics — 4.08

# %% [markdown]
# 10.  Identify any potential areas for improvement or optimization based on the data analysis.
#
# - Some prices, ratings, and reviews are incomplete.
#
# - A few categories dominate the dataset.
#
# - Discounts vary too much across products.
#
# - Ratings do not strongly match product quality.
#
# - Some product names and reviews repeat.

# %% [markdown]
# EDA-4
# 1.  Read the dataframe, check null value if present then do the needful, check duplicate row , if present then do
# the needful?
# - Null values:
# There are 0 null values in any column of the dataframe.
# → No cleaning needed for nulls.
#
# - Duplicate rows:
# The dataset contains 27 duplicate rows.
# → All duplicate rows were removed to clean the data.

# %% [markdown]
# 2. What is the distribution of popularity among the tracks in the dataset? Visualize it using a histogram?
# - he popularity distribution is mostly concentrated between 70 and 90, showing that most hip-hop tracks in the dataset are highly popular, with very few low-popularity tracks.

# %% [markdown]
# 3.  Is there any relationship between the popularity and the duration of tracks? Explore this using a scatter plot?
# - The scatter plot shows no strong relationship between track duration and popularity.
# Tracks of all lengths have mixed popularity scores, meaning duration does not significantly affect how popular a hip-hop track becomes.

# %% [markdown]
# 4. Which artist has the highest number of tracks in the dataset? Display the count of tracks for each artist using
# a countplot?
# - Drake has the highest number of tracks in the dataset, with a total of 20 tracks.
# Other top artists include Travis Scott (12), 21 Savage (11), and Lil Nas X (11).

# %% [markdown]
# 5. What are the top 5 least popular tracks in the dataset? Provide the artist name and track name for each?
# - Top 5 least popular tracks:
#
# Pressa – Attachments (feat. Coi Leray) — Popularity 29
#
# Justin Bieber – Intentions — Popularity 35
#
# French Montana – Splash Brothers — Popularity 44
#
# French Montana – Splash Brothers — Popularity 44
#
# Lil Baby – On Me (Remix) — Popularity 47

# %% [markdown]
# 6. Among the top 5 most popular artists, which artist has the highest popularity on average? Calculate and
# display the average popularity for each artist?
# - Among the top 5 most popular artists (by number of tracks), the average popularity is:
#
# Travis Scott — 87.00 - highest
#
# ¥$ — 86.09
#
# 21 Savage — 84.18
#
# Drake — 83.50
#
# Lil Nas X — 76.09
#
# ✔ Highest Average Popularity: Travis Scott

# %% [markdown]
# 7. For the top 5 most popular artists, what are their most popular tracks? List the track name for each artist?
# - Top 5 most popular artists & their most popular tracks:
#
# 1. Travis Scott
# - SICKO MODE (Popularity: 92)
#
# 2. ¥$
# - IDGAF (feat. Yeat) (Popularity: 90)
#
# 3. 21 Savage
# - Rich Baby Daddy (feat. Sexyy Red & SZA) (Popularity: 92)
#
# 4. Drake
# - Rich Baby Daddy (feat. Sexyy Red & SZA) (Popularity: 92)
#
# 5. Lil Nas X
# - OLD TOWN ROAD – REMIX (Popularity: 96)

# %% [markdown]
# 8. Visualize relationships between multiple numerical variables simultaneously using a pair plot?
# - A pair-plot normally shows relationships between numerical variables such as:
#
# Popularity
#
# Duration (ms)
#
# From the data:
#
# Popularity and duration show no strong relationship.
#
# Most tracks cluster in the high-popularity range (80–95).
#
# Duration varies widely but does not affect popularity.
#
# Overall, numerical variables show weak or no correlation with one another.

# %% [markdown]
# 9.  Does the duration of tracks vary significantly across different artists? Explore this visually using a box plot or
# violin plot?
# - Yes, track duration varies across artists.
# Some artists consistently produce longer tracks, while others release shorter, more compact songs.
# Overall, there is clear variation in duration between different artists, showing that each artist follows a different style and track length pattern.

# %% [markdown]
# 10.  How does the distribution of track popularity vary for different artists? Visualize this using a swarm plot or a
# violin plot.
# - The distribution of track popularity clearly varies across artists.
# Some artists (like Drake, Travis Scott, and 21 Savage) consistently have high-popularity tracks, while others show a wider spread, with both medium and low-popularity songs.
# Overall, popularity is not evenly distributed, and top artists tend to have tighter clusters of high-scoring tracks.
